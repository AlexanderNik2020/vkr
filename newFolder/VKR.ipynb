# %%
from rdflib import Graph
from rdflib import Namespace
from rdflib.namespace import FOAF, NamespaceManager, DCTERMS
from rdflib import URIRef, Literal, BNode
import pandas as pd
import numpy as np

# %%
dataframe = pd.read_excel('data.xls', index_col=None, header=0)
massive = dataframe.to_numpy()

# %%
THIS = Namespace("http://irnok.net/ontology/geopollution/pollutiondb")
BASE = Namespace("http://irnok.net/ontology/geopollution/pollutiondb#")
GP = Namespace("http://irnok.net/ontology/geopollution#")
DBP = Namespace("http://dbpedia.org/page/")
OWL = Namespace("http://www.w3.org/2002/07/owl#")
RDF = Namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#")
WGS = Namespace("http://www.w3.org/2003/01/geo/wgs84_pos#")
XML = Namespace("http://www.w3.org/XML/1998/namespace")
XSD = Namespace("http://www.w3.org/2001/XMLSchema#")
RDFS = Namespace("http://www.w3.org/2000/01/rdf-schema#")

# %%
graph = Graph()

# %%
#graph.bind('this',BASE)
graph.bind('gp',GP)
graph.bind('dbp',DBP)
graph.bind('owl',OWL)
graph.bind('rdf',RDF)
graph.bind('wgs',WGS)
graph.bind('xml',XML)
graph.bind('xsd',XSD)
graph.bind('rdfs',RDFS)

# %%
#Ontology annotation
BASE = URIRef("http://irnok.net/ontology/geopollution/pollutiondb")
graph.add((BASE, RDF.type, OWL.Ontology))
graph.add((BASE, RDFS.label, Literal('Database of Pollutions on Olkhon Island',lang='en')))
graph.add((BASE, RDFS.label, Literal('База данных загрязнений на острове Ольхон',lang='ru')))
graph.add((BASE , RDF.type, OWL.NamedIndividual))
graph.add((BASE , RDF.type, DBP.Database))
# Out:
# <Graph identifier=Nef187508916b42f3967601cd2f1b7b1b (<class 'rdflib.graph.Graph'>)>

# %%
#Annotation properties
graph.add((GP.amount, RDF.type, OWL.AnnotationProperty))
graph.add((GP.pollutedBy, RDF.type, OWL.AnnotationProperty))
graph.add((GP.unit, RDF.type, OWL.AnnotationProperty))
graph.add((THIS.contains, RDF.type, OWL.AnnotationProperty)) 
graph.add((WGS.lat, RDF.type, OWL.AnnotationProperty))
graph.add((WGS.long, RDF.type, OWL.AnnotationProperty))
# Out:
# <Graph identifier=Nef187508916b42f3967601cd2f1b7b1b (<class 'rdflib.graph.Graph'>)>

# %%
#Classes
graph.add((DBP.Sample, RDF.type, OWL.Class))
graph.add((DBP.Database, RDF.type, OWL.Class))
# Out:
# <Graph identifier=Nef187508916b42f3967601cd2f1b7b1b (<class 'rdflib.graph.Graph'>)>

# %%
#Individuals

    

for i in range(dataframe.shape[0]):
    currentSample = URIRef(dataframe['name'][i])
    graph.add((BASE + currentSample, RDF.type, OWL.NamedIndividual))
    graph.add((BASE + currentSample, RDF.type, DBP.Sample))
    graph.add((BASE + currentSample, WGS.lat, Literal(np.format_float_positional(float(dataframe['lat'][i])))))
    graph.add((BASE + currentSample, WGS.long, Literal(np.format_float_positional(float(dataframe['long'][i])))))
    for j in range(3,dataframe.shape[1]):
        currentSampleElement = dataframe.columns[j]
        currentSampleName = URIRef(currentSample+'-'+currentSampleElement+'-amount')
        graph.add((BASE + currentSample, THIS.contains, BASE + currentSampleName))

# %%
#Annotation
for i in range(dataframe.shape[0]):
    currentSampleName = dataframe['name'][i]
    for j in range(3,dataframe.shape[1]):
        currentSampleElement = dataframe.columns[j]
        currentSample = URIRef(currentSampleName+'-'+currentSampleElement+'-amount')
        graph.add((BASE + currentSample, GP.pollutedBy, DBP[currentSampleElement]))
        if (str(massive[i][j]).__contains__('<') is False):
            graph.add((BASE + currentSample, GP.amount, Literal(np.format_float_positional(float(massive[i][j])))))
        else:
            graph.add((BASE + currentSample, GP.amount, Literal(np.format_float_positional(float(massive[i][j].split('<')[-1])))))
        graph.add((BASE + currentSample, GP.unit, DBP.Percentage))

# %%
print(graph.serialize(format='ttl', base = BASE))
# Out:
# @base <http://irnok.net/ontology/geopollution/pollutiondb> .
# @prefix dbp: <http://dbpedia.org/page/> .
# @prefix gp: <http://irnok.net/ontology/geopollution#> .
# @prefix ns1: <http://irnok.net/ontology/geopollution/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix wgs: <http://www.w3.org/2003/01/geo/wgs84_pos#> .
#
# gp:amount a owl:AnnotationProperty .
#
# gp:pollutedBy a owl:AnnotationProperty .
#
# gp:unit a owl:AnnotationProperty .
#
# <> a dbp:Database,
#         owl:NamedIndividual,
#         owl:Ontology ;
#     rdfs:label "Database of Pollutions on Olkhon Island"@en,
#         "База данных загрязнений на острове Ольхон"@ru .
#
# <UGS-0211> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0211-Aluminium_oxide-amount>,
#         <UGS-0211-Arsenic-amount>,
#         <UGS-0211-Barium-amount>,
#         <UGS-0211-Calcium_oxide-amount>,
#         <UGS-0211-Carbon-amount>,
#         <UGS-0211-Cerium-amount>,
#         <UGS-0211-Chromium-amount>,
#         <UGS-0211-Cobalt-amount>,
#         <UGS-0211-Copper-amount>,
#         <UGS-0211-Fluorine-amount>,
#         <UGS-0211-Gallium-amount>,
#         <UGS-0211-Iron(III)_oxide-amount>,
#         <UGS-0211-Lanthanum-amount>,
#         <UGS-0211-Lead-amount>,
#         <UGS-0211-Magnesium_oxide-amount>,
#         <UGS-0211-Manganese(II)_oxide-amount>,
#         <UGS-0211-Neodymium-amount>,
#         <UGS-0211-Nickel-amount>,
#         <UGS-0211-Niobium-amount>,
#         <UGS-0211-Phosphorus_trioxide-amount>,
#         <UGS-0211-Potassium_oxide-amount>,
#         <UGS-0211-Rubidium-amount>,
#         <UGS-0211-Silicon_dioxide-amount>,
#         <UGS-0211-Sodium_oxide-amount>,
#         <UGS-0211-Strontium-amount>,
#         <UGS-0211-Sulfur-amount>,
#         <UGS-0211-Thorium-amount>,
#         <UGS-0211-Tin-amount>,
#         <UGS-0211-Titanium_dioxide-amount>,
#         <UGS-0211-Tungsten-amount>,
#         <UGS-0211-Uranium-amount>,
#         <UGS-0211-Vanadium-amount>,
#         <UGS-0211-Yttrium-amount>,
#         <UGS-0211-Zinc-amount>,
#         <UGS-0211-Zirconium-amount> ;
#     wgs:lat "53.149529993534" ;
#     wgs:long "107.406912976875" .
#
# <UGS-0212> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0212-Aluminium_oxide-amount>,
#         <UGS-0212-Arsenic-amount>,
#         <UGS-0212-Barium-amount>,
#         <UGS-0212-Calcium_oxide-amount>,
#         <UGS-0212-Carbon-amount>,
#         <UGS-0212-Cerium-amount>,
#         <UGS-0212-Chromium-amount>,
#         <UGS-0212-Cobalt-amount>,
#         <UGS-0212-Copper-amount>,
#         <UGS-0212-Fluorine-amount>,
#         <UGS-0212-Gallium-amount>,
#         <UGS-0212-Iron(III)_oxide-amount>,
#         <UGS-0212-Lanthanum-amount>,
#         <UGS-0212-Lead-amount>,
#         <UGS-0212-Magnesium_oxide-amount>,
#         <UGS-0212-Manganese(II)_oxide-amount>,
#         <UGS-0212-Neodymium-amount>,
#         <UGS-0212-Nickel-amount>,
#         <UGS-0212-Niobium-amount>,
#         <UGS-0212-Phosphorus_trioxide-amount>,
#         <UGS-0212-Potassium_oxide-amount>,
#         <UGS-0212-Rubidium-amount>,
#         <UGS-0212-Silicon_dioxide-amount>,
#         <UGS-0212-Sodium_oxide-amount>,
#         <UGS-0212-Strontium-amount>,
#         <UGS-0212-Sulfur-amount>,
#         <UGS-0212-Thorium-amount>,
#         <UGS-0212-Tin-amount>,
#         <UGS-0212-Titanium_dioxide-amount>,
#         <UGS-0212-Tungsten-amount>,
#         <UGS-0212-Uranium-amount>,
#         <UGS-0212-Vanadium-amount>,
#         <UGS-0212-Yttrium-amount>,
#         <UGS-0212-Zinc-amount>,
#         <UGS-0212-Zirconium-amount> ;
#     wgs:lat "53.1585080176591" ;
#     wgs:long "107.407415974885" .
#
# <UGS-0214> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0214-Aluminium_oxide-amount>,
#         <UGS-0214-Arsenic-amount>,
#         <UGS-0214-Barium-amount>,
#         <UGS-0214-Calcium_oxide-amount>,
#         <UGS-0214-Carbon-amount>,
#         <UGS-0214-Cerium-amount>,
#         <UGS-0214-Chromium-amount>,
#         <UGS-0214-Cobalt-amount>,
#         <UGS-0214-Copper-amount>,
#         <UGS-0214-Fluorine-amount>,
#         <UGS-0214-Gallium-amount>,
#         <UGS-0214-Iron(III)_oxide-amount>,
#         <UGS-0214-Lanthanum-amount>,
#         <UGS-0214-Lead-amount>,
#         <UGS-0214-Magnesium_oxide-amount>,
#         <UGS-0214-Manganese(II)_oxide-amount>,
#         <UGS-0214-Neodymium-amount>,
#         <UGS-0214-Nickel-amount>,
#         <UGS-0214-Niobium-amount>,
#         <UGS-0214-Phosphorus_trioxide-amount>,
#         <UGS-0214-Potassium_oxide-amount>,
#         <UGS-0214-Rubidium-amount>,
#         <UGS-0214-Silicon_dioxide-amount>,
#         <UGS-0214-Sodium_oxide-amount>,
#         <UGS-0214-Strontium-amount>,
#         <UGS-0214-Sulfur-amount>,
#         <UGS-0214-Thorium-amount>,
#         <UGS-0214-Tin-amount>,
#         <UGS-0214-Titanium_dioxide-amount>,
#         <UGS-0214-Tungsten-amount>,
#         <UGS-0214-Uranium-amount>,
#         <UGS-0214-Vanadium-amount>,
#         <UGS-0214-Yttrium-amount>,
#         <UGS-0214-Zinc-amount>,
#         <UGS-0214-Zirconium-amount> ;
#     wgs:lat "53.158809011802" ;
#     wgs:long "107.392479004338" .
#
# <UGS-0215> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0215-Aluminium_oxide-amount>,
#         <UGS-0215-Arsenic-amount>,
#         <UGS-0215-Barium-amount>,
#         <UGS-0215-Calcium_oxide-amount>,
#         <UGS-0215-Carbon-amount>,
#         <UGS-0215-Cerium-amount>,
#         <UGS-0215-Chromium-amount>,
#         <UGS-0215-Cobalt-amount>,
#         <UGS-0215-Copper-amount>,
#         <UGS-0215-Fluorine-amount>,
#         <UGS-0215-Gallium-amount>,
#         <UGS-0215-Iron(III)_oxide-amount>,
#         <UGS-0215-Lanthanum-amount>,
#         <UGS-0215-Lead-amount>,
#         <UGS-0215-Magnesium_oxide-amount>,
#         <UGS-0215-Manganese(II)_oxide-amount>,
#         <UGS-0215-Neodymium-amount>,
#         <UGS-0215-Nickel-amount>,
#         <UGS-0215-Niobium-amount>,
#         <UGS-0215-Phosphorus_trioxide-amount>,
#         <UGS-0215-Potassium_oxide-amount>,
#         <UGS-0215-Rubidium-amount>,
#         <UGS-0215-Silicon_dioxide-amount>,
#         <UGS-0215-Sodium_oxide-amount>,
#         <UGS-0215-Strontium-amount>,
#         <UGS-0215-Sulfur-amount>,
#         <UGS-0215-Thorium-amount>,
#         <UGS-0215-Tin-amount>,
#         <UGS-0215-Titanium_dioxide-amount>,
#         <UGS-0215-Tungsten-amount>,
#         <UGS-0215-Uranium-amount>,
#         <UGS-0215-Vanadium-amount>,
#         <UGS-0215-Yttrium-amount>,
#         <UGS-0215-Zinc-amount>,
#         <UGS-0215-Zirconium-amount> ;
#     wgs:lat "53.1541699636727" ;
#     wgs:long "107.399696996435" .
#
# <UGS-0216> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0216-Aluminium_oxide-amount>,
#         <UGS-0216-Arsenic-amount>,
#         <UGS-0216-Barium-amount>,
#         <UGS-0216-Calcium_oxide-amount>,
#         <UGS-0216-Carbon-amount>,
#         <UGS-0216-Cerium-amount>,
#         <UGS-0216-Chromium-amount>,
#         <UGS-0216-Cobalt-amount>,
#         <UGS-0216-Copper-amount>,
#         <UGS-0216-Fluorine-amount>,
#         <UGS-0216-Gallium-amount>,
#         <UGS-0216-Iron(III)_oxide-amount>,
#         <UGS-0216-Lanthanum-amount>,
#         <UGS-0216-Lead-amount>,
#         <UGS-0216-Magnesium_oxide-amount>,
#         <UGS-0216-Manganese(II)_oxide-amount>,
#         <UGS-0216-Neodymium-amount>,
#         <UGS-0216-Nickel-amount>,
#         <UGS-0216-Niobium-amount>,
#         <UGS-0216-Phosphorus_trioxide-amount>,
#         <UGS-0216-Potassium_oxide-amount>,
#         <UGS-0216-Rubidium-amount>,
#         <UGS-0216-Silicon_dioxide-amount>,
#         <UGS-0216-Sodium_oxide-amount>,
#         <UGS-0216-Strontium-amount>,
#         <UGS-0216-Sulfur-amount>,
#         <UGS-0216-Thorium-amount>,
#         <UGS-0216-Tin-amount>,
#         <UGS-0216-Titanium_dioxide-amount>,
#         <UGS-0216-Tungsten-amount>,
#         <UGS-0216-Uranium-amount>,
#         <UGS-0216-Vanadium-amount>,
#         <UGS-0216-Yttrium-amount>,
#         <UGS-0216-Zinc-amount>,
#         <UGS-0216-Zirconium-amount> ;
#     wgs:lat "53.1498309876769" ;
#     wgs:long "107.391980029642" .
#
# <UGS-0217> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0217-Aluminium_oxide-amount>,
#         <UGS-0217-Arsenic-amount>,
#         <UGS-0217-Barium-amount>,
#         <UGS-0217-Calcium_oxide-amount>,
#         <UGS-0217-Carbon-amount>,
#         <UGS-0217-Cerium-amount>,
#         <UGS-0217-Chromium-amount>,
#         <UGS-0217-Cobalt-amount>,
#         <UGS-0217-Copper-amount>,
#         <UGS-0217-Fluorine-amount>,
#         <UGS-0217-Gallium-amount>,
#         <UGS-0217-Iron(III)_oxide-amount>,
#         <UGS-0217-Lanthanum-amount>,
#         <UGS-0217-Lead-amount>,
#         <UGS-0217-Magnesium_oxide-amount>,
#         <UGS-0217-Manganese(II)_oxide-amount>,
#         <UGS-0217-Neodymium-amount>,
#         <UGS-0217-Nickel-amount>,
#         <UGS-0217-Niobium-amount>,
#         <UGS-0217-Phosphorus_trioxide-amount>,
#         <UGS-0217-Potassium_oxide-amount>,
#         <UGS-0217-Rubidium-amount>,
#         <UGS-0217-Silicon_dioxide-amount>,
#         <UGS-0217-Sodium_oxide-amount>,
#         <UGS-0217-Strontium-amount>,
#         <UGS-0217-Sulfur-amount>,
#         <UGS-0217-Thorium-amount>,
#         <UGS-0217-Tin-amount>,
#         <UGS-0217-Titanium_dioxide-amount>,
#         <UGS-0217-Tungsten-amount>,
#         <UGS-0217-Uranium-amount>,
#         <UGS-0217-Vanadium-amount>,
#         <UGS-0217-Yttrium-amount>,
#         <UGS-0217-Zinc-amount>,
#         <UGS-0217-Zirconium-amount> ;
#     wgs:lat "53.1544700358062" ;
#     wgs:long "107.384762037545" .
#
# <UGS-0218> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0218-Aluminium_oxide-amount>,
#         <UGS-0218-Arsenic-amount>,
#         <UGS-0218-Barium-amount>,
#         <UGS-0218-Calcium_oxide-amount>,
#         <UGS-0218-Carbon-amount>,
#         <UGS-0218-Cerium-amount>,
#         <UGS-0218-Chromium-amount>,
#         <UGS-0218-Cobalt-amount>,
#         <UGS-0218-Copper-amount>,
#         <UGS-0218-Fluorine-amount>,
#         <UGS-0218-Gallium-amount>,
#         <UGS-0218-Iron(III)_oxide-amount>,
#         <UGS-0218-Lanthanum-amount>,
#         <UGS-0218-Lead-amount>,
#         <UGS-0218-Magnesium_oxide-amount>,
#         <UGS-0218-Manganese(II)_oxide-amount>,
#         <UGS-0218-Neodymium-amount>,
#         <UGS-0218-Nickel-amount>,
#         <UGS-0218-Niobium-amount>,
#         <UGS-0218-Phosphorus_trioxide-amount>,
#         <UGS-0218-Potassium_oxide-amount>,
#         <UGS-0218-Rubidium-amount>,
#         <UGS-0218-Silicon_dioxide-amount>,
#         <UGS-0218-Sodium_oxide-amount>,
#         <UGS-0218-Strontium-amount>,
#         <UGS-0218-Sulfur-amount>,
#         <UGS-0218-Thorium-amount>,
#         <UGS-0218-Tin-amount>,
#         <UGS-0218-Titanium_dioxide-amount>,
#         <UGS-0218-Tungsten-amount>,
#         <UGS-0218-Uranium-amount>,
#         <UGS-0218-Vanadium-amount>,
#         <UGS-0218-Yttrium-amount>,
#         <UGS-0218-Zinc-amount>,
#         <UGS-0218-Zirconium-amount> ;
#     wgs:lat "53.1634479761123" ;
#     wgs:long "107.385260006412" .
#
# <UGS-0219> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0219-Aluminium_oxide-amount>,
#         <UGS-0219-Arsenic-amount>,
#         <UGS-0219-Barium-amount>,
#         <UGS-0219-Calcium_oxide-amount>,
#         <UGS-0219-Carbon-amount>,
#         <UGS-0219-Cerium-amount>,
#         <UGS-0219-Chromium-amount>,
#         <UGS-0219-Cobalt-amount>,
#         <UGS-0219-Copper-amount>,
#         <UGS-0219-Fluorine-amount>,
#         <UGS-0219-Gallium-amount>,
#         <UGS-0219-Iron(III)_oxide-amount>,
#         <UGS-0219-Lanthanum-amount>,
#         <UGS-0219-Lead-amount>,
#         <UGS-0219-Magnesium_oxide-amount>,
#         <UGS-0219-Manganese(II)_oxide-amount>,
#         <UGS-0219-Neodymium-amount>,
#         <UGS-0219-Nickel-amount>,
#         <UGS-0219-Niobium-amount>,
#         <UGS-0219-Phosphorus_trioxide-amount>,
#         <UGS-0219-Potassium_oxide-amount>,
#         <UGS-0219-Rubidium-amount>,
#         <UGS-0219-Silicon_dioxide-amount>,
#         <UGS-0219-Sodium_oxide-amount>,
#         <UGS-0219-Strontium-amount>,
#         <UGS-0219-Sulfur-amount>,
#         <UGS-0219-Thorium-amount>,
#         <UGS-0219-Tin-amount>,
#         <UGS-0219-Titanium_dioxide-amount>,
#         <UGS-0219-Tungsten-amount>,
#         <UGS-0219-Uranium-amount>,
#         <UGS-0219-Vanadium-amount>,
#         <UGS-0219-Yttrium-amount>,
#         <UGS-0219-Zinc-amount>,
#         <UGS-0219-Zirconium-amount> ;
#     wgs:lat "53.1680860184133" ;
#     wgs:long "107.378037991002" .
#
# <UGS-0220> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0220-Aluminium_oxide-amount>,
#         <UGS-0220-Arsenic-amount>,
#         <UGS-0220-Barium-amount>,
#         <UGS-0220-Calcium_oxide-amount>,
#         <UGS-0220-Carbon-amount>,
#         <UGS-0220-Cerium-amount>,
#         <UGS-0220-Chromium-amount>,
#         <UGS-0220-Cobalt-amount>,
#         <UGS-0220-Copper-amount>,
#         <UGS-0220-Fluorine-amount>,
#         <UGS-0220-Gallium-amount>,
#         <UGS-0220-Iron(III)_oxide-amount>,
#         <UGS-0220-Lanthanum-amount>,
#         <UGS-0220-Lead-amount>,
#         <UGS-0220-Magnesium_oxide-amount>,
#         <UGS-0220-Manganese(II)_oxide-amount>,
#         <UGS-0220-Neodymium-amount>,
#         <UGS-0220-Nickel-amount>,
#         <UGS-0220-Niobium-amount>,
#         <UGS-0220-Phosphorus_trioxide-amount>,
#         <UGS-0220-Potassium_oxide-amount>,
#         <UGS-0220-Rubidium-amount>,
#         <UGS-0220-Silicon_dioxide-amount>,
#         <UGS-0220-Sodium_oxide-amount>,
#         <UGS-0220-Strontium-amount>,
#         <UGS-0220-Sulfur-amount>,
#         <UGS-0220-Thorium-amount>,
#         <UGS-0220-Tin-amount>,
#         <UGS-0220-Titanium_dioxide-amount>,
#         <UGS-0220-Tungsten-amount>,
#         <UGS-0220-Uranium-amount>,
#         <UGS-0220-Vanadium-amount>,
#         <UGS-0220-Yttrium-amount>,
#         <UGS-0220-Zinc-amount>,
#         <UGS-0220-Zirconium-amount> ;
#     wgs:lat "53.1591079942882" ;
#     wgs:long "107.377542033791" .
#
# <UGS-0221> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0221-Aluminium_oxide-amount>,
#         <UGS-0221-Arsenic-amount>,
#         <UGS-0221-Barium-amount>,
#         <UGS-0221-Calcium_oxide-amount>,
#         <UGS-0221-Carbon-amount>,
#         <UGS-0221-Cerium-amount>,
#         <UGS-0221-Chromium-amount>,
#         <UGS-0221-Cobalt-amount>,
#         <UGS-0221-Copper-amount>,
#         <UGS-0221-Fluorine-amount>,
#         <UGS-0221-Gallium-amount>,
#         <UGS-0221-Iron(III)_oxide-amount>,
#         <UGS-0221-Lanthanum-amount>,
#         <UGS-0221-Lead-amount>,
#         <UGS-0221-Magnesium_oxide-amount>,
#         <UGS-0221-Manganese(II)_oxide-amount>,
#         <UGS-0221-Neodymium-amount>,
#         <UGS-0221-Nickel-amount>,
#         <UGS-0221-Niobium-amount>,
#         <UGS-0221-Phosphorus_trioxide-amount>,
#         <UGS-0221-Potassium_oxide-amount>,
#         <UGS-0221-Rubidium-amount>,
#         <UGS-0221-Silicon_dioxide-amount>,
#         <UGS-0221-Sodium_oxide-amount>,
#         <UGS-0221-Strontium-amount>,
#         <UGS-0221-Sulfur-amount>,
#         <UGS-0221-Thorium-amount>,
#         <UGS-0221-Tin-amount>,
#         <UGS-0221-Titanium_dioxide-amount>,
#         <UGS-0221-Tungsten-amount>,
#         <UGS-0221-Uranium-amount>,
#         <UGS-0221-Vanadium-amount>,
#         <UGS-0221-Yttrium-amount>,
#         <UGS-0221-Zinc-amount>,
#         <UGS-0221-Zirconium-amount> ;
#     wgs:lat "53.1408539693802" ;
#     wgs:long "107.391480971127" .
#
# <UGS-0222> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0222-Aluminium_oxide-amount>,
#         <UGS-0222-Arsenic-amount>,
#         <UGS-0222-Barium-amount>,
#         <UGS-0222-Calcium_oxide-amount>,
#         <UGS-0222-Carbon-amount>,
#         <UGS-0222-Cerium-amount>,
#         <UGS-0222-Chromium-amount>,
#         <UGS-0222-Cobalt-amount>,
#         <UGS-0222-Copper-amount>,
#         <UGS-0222-Fluorine-amount>,
#         <UGS-0222-Gallium-amount>,
#         <UGS-0222-Iron(III)_oxide-amount>,
#         <UGS-0222-Lanthanum-amount>,
#         <UGS-0222-Lead-amount>,
#         <UGS-0222-Magnesium_oxide-amount>,
#         <UGS-0222-Manganese(II)_oxide-amount>,
#         <UGS-0222-Neodymium-amount>,
#         <UGS-0222-Nickel-amount>,
#         <UGS-0222-Niobium-amount>,
#         <UGS-0222-Phosphorus_trioxide-amount>,
#         <UGS-0222-Potassium_oxide-amount>,
#         <UGS-0222-Rubidium-amount>,
#         <UGS-0222-Silicon_dioxide-amount>,
#         <UGS-0222-Sodium_oxide-amount>,
#         <UGS-0222-Strontium-amount>,
#         <UGS-0222-Sulfur-amount>,
#         <UGS-0222-Thorium-amount>,
#         <UGS-0222-Tin-amount>,
#         <UGS-0222-Titanium_dioxide-amount>,
#         <UGS-0222-Tungsten-amount>,
#         <UGS-0222-Uranium-amount>,
#         <UGS-0222-Vanadium-amount>,
#         <UGS-0222-Yttrium-amount>,
#         <UGS-0222-Zinc-amount>,
#         <UGS-0222-Zirconium-amount> ;
#     wgs:lat "53.1451920233666" ;
#     wgs:long "107.399196010082" .
#
# <UGS-0224> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0224-Aluminium_oxide-amount>,
#         <UGS-0224-Arsenic-amount>,
#         <UGS-0224-Barium-amount>,
#         <UGS-0224-Calcium_oxide-amount>,
#         <UGS-0224-Carbon-amount>,
#         <UGS-0224-Cerium-amount>,
#         <UGS-0224-Chromium-amount>,
#         <UGS-0224-Cobalt-amount>,
#         <UGS-0224-Copper-amount>,
#         <UGS-0224-Fluorine-amount>,
#         <UGS-0224-Gallium-amount>,
#         <UGS-0224-Iron(III)_oxide-amount>,
#         <UGS-0224-Lanthanum-amount>,
#         <UGS-0224-Lead-amount>,
#         <UGS-0224-Magnesium_oxide-amount>,
#         <UGS-0224-Manganese(II)_oxide-amount>,
#         <UGS-0224-Neodymium-amount>,
#         <UGS-0224-Nickel-amount>,
#         <UGS-0224-Niobium-amount>,
#         <UGS-0224-Phosphorus_trioxide-amount>,
#         <UGS-0224-Potassium_oxide-amount>,
#         <UGS-0224-Rubidium-amount>,
#         <UGS-0224-Silicon_dioxide-amount>,
#         <UGS-0224-Sodium_oxide-amount>,
#         <UGS-0224-Strontium-amount>,
#         <UGS-0224-Sulfur-amount>,
#         <UGS-0224-Thorium-amount>,
#         <UGS-0224-Tin-amount>,
#         <UGS-0224-Titanium_dioxide-amount>,
#         <UGS-0224-Tungsten-amount>,
#         <UGS-0224-Uranium-amount>,
#         <UGS-0224-Vanadium-amount>,
#         <UGS-0224-Yttrium-amount>,
#         <UGS-0224-Zinc-amount>,
#         <UGS-0224-Zirconium-amount> ;
#     wgs:lat "53.1538679637014" ;
#     wgs:long "107.414632039144" .
#
# <UGS-0225> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0225-Aluminium_oxide-amount>,
#         <UGS-0225-Arsenic-amount>,
#         <UGS-0225-Barium-amount>,
#         <UGS-0225-Calcium_oxide-amount>,
#         <UGS-0225-Carbon-amount>,
#         <UGS-0225-Cerium-amount>,
#         <UGS-0225-Chromium-amount>,
#         <UGS-0225-Cobalt-amount>,
#         <UGS-0225-Copper-amount>,
#         <UGS-0225-Fluorine-amount>,
#         <UGS-0225-Gallium-amount>,
#         <UGS-0225-Iron(III)_oxide-amount>,
#         <UGS-0225-Lanthanum-amount>,
#         <UGS-0225-Lead-amount>,
#         <UGS-0225-Magnesium_oxide-amount>,
#         <UGS-0225-Manganese(II)_oxide-amount>,
#         <UGS-0225-Neodymium-amount>,
#         <UGS-0225-Nickel-amount>,
#         <UGS-0225-Niobium-amount>,
#         <UGS-0225-Phosphorus_trioxide-amount>,
#         <UGS-0225-Potassium_oxide-amount>,
#         <UGS-0225-Rubidium-amount>,
#         <UGS-0225-Silicon_dioxide-amount>,
#         <UGS-0225-Sodium_oxide-amount>,
#         <UGS-0225-Strontium-amount>,
#         <UGS-0225-Sulfur-amount>,
#         <UGS-0225-Thorium-amount>,
#         <UGS-0225-Tin-amount>,
#         <UGS-0225-Titanium_dioxide-amount>,
#         <UGS-0225-Tungsten-amount>,
#         <UGS-0225-Uranium-amount>,
#         <UGS-0225-Vanadium-amount>,
#         <UGS-0225-Yttrium-amount>,
#         <UGS-0225-Zinc-amount>,
#         <UGS-0225-Zirconium-amount> ;
#     wgs:lat "53.1448900233954" ;
#     wgs:long "107.414128035306" .
#
# <UGS-0227> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0227-Aluminium_oxide-amount>,
#         <UGS-0227-Arsenic-amount>,
#         <UGS-0227-Barium-amount>,
#         <UGS-0227-Calcium_oxide-amount>,
#         <UGS-0227-Carbon-amount>,
#         <UGS-0227-Cerium-amount>,
#         <UGS-0227-Chromium-amount>,
#         <UGS-0227-Cobalt-amount>,
#         <UGS-0227-Copper-amount>,
#         <UGS-0227-Fluorine-amount>,
#         <UGS-0227-Gallium-amount>,
#         <UGS-0227-Iron(III)_oxide-amount>,
#         <UGS-0227-Lanthanum-amount>,
#         <UGS-0227-Lead-amount>,
#         <UGS-0227-Magnesium_oxide-amount>,
#         <UGS-0227-Manganese(II)_oxide-amount>,
#         <UGS-0227-Neodymium-amount>,
#         <UGS-0227-Nickel-amount>,
#         <UGS-0227-Niobium-amount>,
#         <UGS-0227-Phosphorus_trioxide-amount>,
#         <UGS-0227-Potassium_oxide-amount>,
#         <UGS-0227-Rubidium-amount>,
#         <UGS-0227-Silicon_dioxide-amount>,
#         <UGS-0227-Sodium_oxide-amount>,
#         <UGS-0227-Strontium-amount>,
#         <UGS-0227-Sulfur-amount>,
#         <UGS-0227-Thorium-amount>,
#         <UGS-0227-Tin-amount>,
#         <UGS-0227-Titanium_dioxide-amount>,
#         <UGS-0227-Tungsten-amount>,
#         <UGS-0227-Uranium-amount>,
#         <UGS-0227-Vanadium-amount>,
#         <UGS-0227-Yttrium-amount>,
#         <UGS-0227-Zinc-amount>,
#         <UGS-0227-Zirconium-amount> ;
#     wgs:lat "53.1359130050987" ;
#     wgs:long "107.413625037297" .
#
# <UGS-0228> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0228-Aluminium_oxide-amount>,
#         <UGS-0228-Arsenic-amount>,
#         <UGS-0228-Barium-amount>,
#         <UGS-0228-Calcium_oxide-amount>,
#         <UGS-0228-Carbon-amount>,
#         <UGS-0228-Cerium-amount>,
#         <UGS-0228-Chromium-amount>,
#         <UGS-0228-Cobalt-amount>,
#         <UGS-0228-Copper-amount>,
#         <UGS-0228-Fluorine-amount>,
#         <UGS-0228-Gallium-amount>,
#         <UGS-0228-Iron(III)_oxide-amount>,
#         <UGS-0228-Lanthanum-amount>,
#         <UGS-0228-Lead-amount>,
#         <UGS-0228-Magnesium_oxide-amount>,
#         <UGS-0228-Manganese(II)_oxide-amount>,
#         <UGS-0228-Neodymium-amount>,
#         <UGS-0228-Nickel-amount>,
#         <UGS-0228-Niobium-amount>,
#         <UGS-0228-Phosphorus_trioxide-amount>,
#         <UGS-0228-Potassium_oxide-amount>,
#         <UGS-0228-Rubidium-amount>,
#         <UGS-0228-Silicon_dioxide-amount>,
#         <UGS-0228-Sodium_oxide-amount>,
#         <UGS-0228-Strontium-amount>,
#         <UGS-0228-Sulfur-amount>,
#         <UGS-0228-Thorium-amount>,
#         <UGS-0228-Tin-amount>,
#         <UGS-0228-Titanium_dioxide-amount>,
#         <UGS-0228-Tungsten-amount>,
#         <UGS-0228-Uranium-amount>,
#         <UGS-0228-Vanadium-amount>,
#         <UGS-0228-Yttrium-amount>,
#         <UGS-0228-Zinc-amount>,
#         <UGS-0228-Zirconium-amount> ;
#     wgs:lat "53.1315750349313" ;
#     wgs:long "107.405908992514" .
#
# <UGS-0229> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0229-Aluminium_oxide-amount>,
#         <UGS-0229-Arsenic-amount>,
#         <UGS-0229-Barium-amount>,
#         <UGS-0229-Calcium_oxide-amount>,
#         <UGS-0229-Carbon-amount>,
#         <UGS-0229-Cerium-amount>,
#         <UGS-0229-Chromium-amount>,
#         <UGS-0229-Cobalt-amount>,
#         <UGS-0229-Copper-amount>,
#         <UGS-0229-Fluorine-amount>,
#         <UGS-0229-Gallium-amount>,
#         <UGS-0229-Iron(III)_oxide-amount>,
#         <UGS-0229-Lanthanum-amount>,
#         <UGS-0229-Lead-amount>,
#         <UGS-0229-Magnesium_oxide-amount>,
#         <UGS-0229-Manganese(II)_oxide-amount>,
#         <UGS-0229-Neodymium-amount>,
#         <UGS-0229-Nickel-amount>,
#         <UGS-0229-Niobium-amount>,
#         <UGS-0229-Phosphorus_trioxide-amount>,
#         <UGS-0229-Potassium_oxide-amount>,
#         <UGS-0229-Rubidium-amount>,
#         <UGS-0229-Silicon_dioxide-amount>,
#         <UGS-0229-Sodium_oxide-amount>,
#         <UGS-0229-Strontium-amount>,
#         <UGS-0229-Sulfur-amount>,
#         <UGS-0229-Thorium-amount>,
#         <UGS-0229-Tin-amount>,
#         <UGS-0229-Titanium_dioxide-amount>,
#         <UGS-0229-Tungsten-amount>,
#         <UGS-0229-Uranium-amount>,
#         <UGS-0229-Vanadium-amount>,
#         <UGS-0229-Yttrium-amount>,
#         <UGS-0229-Zinc-amount>,
#         <UGS-0229-Zirconium-amount> ;
#     wgs:lat "53.1225970108062" ;
#     wgs:long "107.405408006161" .
#
# <UGS-0230> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0230-Aluminium_oxide-amount>,
#         <UGS-0230-Arsenic-amount>,
#         <UGS-0230-Barium-amount>,
#         <UGS-0230-Calcium_oxide-amount>,
#         <UGS-0230-Carbon-amount>,
#         <UGS-0230-Cerium-amount>,
#         <UGS-0230-Chromium-amount>,
#         <UGS-0230-Cobalt-amount>,
#         <UGS-0230-Copper-amount>,
#         <UGS-0230-Fluorine-amount>,
#         <UGS-0230-Gallium-amount>,
#         <UGS-0230-Iron(III)_oxide-amount>,
#         <UGS-0230-Lanthanum-amount>,
#         <UGS-0230-Lead-amount>,
#         <UGS-0230-Magnesium_oxide-amount>,
#         <UGS-0230-Manganese(II)_oxide-amount>,
#         <UGS-0230-Neodymium-amount>,
#         <UGS-0230-Nickel-amount>,
#         <UGS-0230-Niobium-amount>,
#         <UGS-0230-Phosphorus_trioxide-amount>,
#         <UGS-0230-Potassium_oxide-amount>,
#         <UGS-0230-Rubidium-amount>,
#         <UGS-0230-Silicon_dioxide-amount>,
#         <UGS-0230-Sodium_oxide-amount>,
#         <UGS-0230-Strontium-amount>,
#         <UGS-0230-Sulfur-amount>,
#         <UGS-0230-Thorium-amount>,
#         <UGS-0230-Tin-amount>,
#         <UGS-0230-Titanium_dioxide-amount>,
#         <UGS-0230-Tungsten-amount>,
#         <UGS-0230-Uranium-amount>,
#         <UGS-0230-Vanadium-amount>,
#         <UGS-0230-Yttrium-amount>,
#         <UGS-0230-Zinc-amount>,
#         <UGS-0230-Zirconium-amount> ;
#     wgs:lat "53.1272369809448" ;
#     wgs:long "107.398195965215" .
#
# <UGS-0231> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0231-Aluminium_oxide-amount>,
#         <UGS-0231-Arsenic-amount>,
#         <UGS-0231-Barium-amount>,
#         <UGS-0231-Calcium_oxide-amount>,
#         <UGS-0231-Carbon-amount>,
#         <UGS-0231-Cerium-amount>,
#         <UGS-0231-Chromium-amount>,
#         <UGS-0231-Cobalt-amount>,
#         <UGS-0231-Copper-amount>,
#         <UGS-0231-Fluorine-amount>,
#         <UGS-0231-Gallium-amount>,
#         <UGS-0231-Iron(III)_oxide-amount>,
#         <UGS-0231-Lanthanum-amount>,
#         <UGS-0231-Lead-amount>,
#         <UGS-0231-Magnesium_oxide-amount>,
#         <UGS-0231-Manganese(II)_oxide-amount>,
#         <UGS-0231-Neodymium-amount>,
#         <UGS-0231-Nickel-amount>,
#         <UGS-0231-Niobium-amount>,
#         <UGS-0231-Phosphorus_trioxide-amount>,
#         <UGS-0231-Potassium_oxide-amount>,
#         <UGS-0231-Rubidium-amount>,
#         <UGS-0231-Silicon_dioxide-amount>,
#         <UGS-0231-Sodium_oxide-amount>,
#         <UGS-0231-Strontium-amount>,
#         <UGS-0231-Sulfur-amount>,
#         <UGS-0231-Thorium-amount>,
#         <UGS-0231-Tin-amount>,
#         <UGS-0231-Titanium_dioxide-amount>,
#         <UGS-0231-Tungsten-amount>,
#         <UGS-0231-Uranium-amount>,
#         <UGS-0231-Vanadium-amount>,
#         <UGS-0231-Yttrium-amount>,
#         <UGS-0231-Zinc-amount>,
#         <UGS-0231-Zirconium-amount> ;
#     wgs:lat "53.1318760290741" ;
#     wgs:long "107.390981996431" .
#
# <UGS-0233> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0233-Aluminium_oxide-amount>,
#         <UGS-0233-Arsenic-amount>,
#         <UGS-0233-Barium-amount>,
#         <UGS-0233-Calcium_oxide-amount>,
#         <UGS-0233-Carbon-amount>,
#         <UGS-0233-Cerium-amount>,
#         <UGS-0233-Chromium-amount>,
#         <UGS-0233-Cobalt-amount>,
#         <UGS-0233-Copper-amount>,
#         <UGS-0233-Fluorine-amount>,
#         <UGS-0233-Gallium-amount>,
#         <UGS-0233-Iron(III)_oxide-amount>,
#         <UGS-0233-Lanthanum-amount>,
#         <UGS-0233-Lead-amount>,
#         <UGS-0233-Magnesium_oxide-amount>,
#         <UGS-0233-Manganese(II)_oxide-amount>,
#         <UGS-0233-Neodymium-amount>,
#         <UGS-0233-Nickel-amount>,
#         <UGS-0233-Niobium-amount>,
#         <UGS-0233-Phosphorus_trioxide-amount>,
#         <UGS-0233-Potassium_oxide-amount>,
#         <UGS-0233-Rubidium-amount>,
#         <UGS-0233-Silicon_dioxide-amount>,
#         <UGS-0233-Sodium_oxide-amount>,
#         <UGS-0233-Strontium-amount>,
#         <UGS-0233-Sulfur-amount>,
#         <UGS-0233-Thorium-amount>,
#         <UGS-0233-Tin-amount>,
#         <UGS-0233-Titanium_dioxide-amount>,
#         <UGS-0233-Tungsten-amount>,
#         <UGS-0233-Uranium-amount>,
#         <UGS-0233-Vanadium-amount>,
#         <UGS-0233-Yttrium-amount>,
#         <UGS-0233-Zinc-amount>,
#         <UGS-0233-Zirconium-amount> ;
#     wgs:lat "53.1405529752373" ;
#     wgs:long "107.406410984694" .
#
# <UGS-0234> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0234-Aluminium_oxide-amount>,
#         <UGS-0234-Arsenic-amount>,
#         <UGS-0234-Barium-amount>,
#         <UGS-0234-Calcium_oxide-amount>,
#         <UGS-0234-Carbon-amount>,
#         <UGS-0234-Cerium-amount>,
#         <UGS-0234-Chromium-amount>,
#         <UGS-0234-Cobalt-amount>,
#         <UGS-0234-Copper-amount>,
#         <UGS-0234-Fluorine-amount>,
#         <UGS-0234-Gallium-amount>,
#         <UGS-0234-Iron(III)_oxide-amount>,
#         <UGS-0234-Lanthanum-amount>,
#         <UGS-0234-Lead-amount>,
#         <UGS-0234-Magnesium_oxide-amount>,
#         <UGS-0234-Manganese(II)_oxide-amount>,
#         <UGS-0234-Neodymium-amount>,
#         <UGS-0234-Nickel-amount>,
#         <UGS-0234-Niobium-amount>,
#         <UGS-0234-Phosphorus_trioxide-amount>,
#         <UGS-0234-Potassium_oxide-amount>,
#         <UGS-0234-Rubidium-amount>,
#         <UGS-0234-Silicon_dioxide-amount>,
#         <UGS-0234-Sodium_oxide-amount>,
#         <UGS-0234-Strontium-amount>,
#         <UGS-0234-Sulfur-amount>,
#         <UGS-0234-Thorium-amount>,
#         <UGS-0234-Tin-amount>,
#         <UGS-0234-Titanium_dioxide-amount>,
#         <UGS-0234-Tungsten-amount>,
#         <UGS-0234-Uranium-amount>,
#         <UGS-0234-Vanadium-amount>,
#         <UGS-0234-Yttrium-amount>,
#         <UGS-0234-Zinc-amount>,
#         <UGS-0234-Zirconium-amount> ;
#     wgs:lat "53.1182590406388" ;
#     wgs:long "107.397695984691" .
#
# <UGS-0235> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0235-Aluminium_oxide-amount>,
#         <UGS-0235-Arsenic-amount>,
#         <UGS-0235-Barium-amount>,
#         <UGS-0235-Calcium_oxide-amount>,
#         <UGS-0235-Carbon-amount>,
#         <UGS-0235-Cerium-amount>,
#         <UGS-0235-Chromium-amount>,
#         <UGS-0235-Cobalt-amount>,
#         <UGS-0235-Copper-amount>,
#         <UGS-0235-Fluorine-amount>,
#         <UGS-0235-Gallium-amount>,
#         <UGS-0235-Iron(III)_oxide-amount>,
#         <UGS-0235-Lanthanum-amount>,
#         <UGS-0235-Lead-amount>,
#         <UGS-0235-Magnesium_oxide-amount>,
#         <UGS-0235-Manganese(II)_oxide-amount>,
#         <UGS-0235-Neodymium-amount>,
#         <UGS-0235-Nickel-amount>,
#         <UGS-0235-Niobium-amount>,
#         <UGS-0235-Phosphorus_trioxide-amount>,
#         <UGS-0235-Potassium_oxide-amount>,
#         <UGS-0235-Rubidium-amount>,
#         <UGS-0235-Silicon_dioxide-amount>,
#         <UGS-0235-Sodium_oxide-amount>,
#         <UGS-0235-Strontium-amount>,
#         <UGS-0235-Sulfur-amount>,
#         <UGS-0235-Thorium-amount>,
#         <UGS-0235-Tin-amount>,
#         <UGS-0235-Titanium_dioxide-amount>,
#         <UGS-0235-Tungsten-amount>,
#         <UGS-0235-Uranium-amount>,
#         <UGS-0235-Vanadium-amount>,
#         <UGS-0235-Yttrium-amount>,
#         <UGS-0235-Zinc-amount>,
#         <UGS-0235-Zirconium-amount> ;
#     wgs:lat "53.122898004949" ;
#     wgs:long "107.390484027564" .
#
# <UGS-0237> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0237-Aluminium_oxide-amount>,
#         <UGS-0237-Arsenic-amount>,
#         <UGS-0237-Barium-amount>,
#         <UGS-0237-Calcium_oxide-amount>,
#         <UGS-0237-Carbon-amount>,
#         <UGS-0237-Cerium-amount>,
#         <UGS-0237-Chromium-amount>,
#         <UGS-0237-Cobalt-amount>,
#         <UGS-0237-Copper-amount>,
#         <UGS-0237-Fluorine-amount>,
#         <UGS-0237-Gallium-amount>,
#         <UGS-0237-Iron(III)_oxide-amount>,
#         <UGS-0237-Lanthanum-amount>,
#         <UGS-0237-Lead-amount>,
#         <UGS-0237-Magnesium_oxide-amount>,
#         <UGS-0237-Manganese(II)_oxide-amount>,
#         <UGS-0237-Neodymium-amount>,
#         <UGS-0237-Nickel-amount>,
#         <UGS-0237-Niobium-amount>,
#         <UGS-0237-Phosphorus_trioxide-amount>,
#         <UGS-0237-Potassium_oxide-amount>,
#         <UGS-0237-Rubidium-amount>,
#         <UGS-0237-Silicon_dioxide-amount>,
#         <UGS-0237-Sodium_oxide-amount>,
#         <UGS-0237-Strontium-amount>,
#         <UGS-0237-Sulfur-amount>,
#         <UGS-0237-Thorium-amount>,
#         <UGS-0237-Tin-amount>,
#         <UGS-0237-Titanium_dioxide-amount>,
#         <UGS-0237-Tungsten-amount>,
#         <UGS-0237-Uranium-amount>,
#         <UGS-0237-Vanadium-amount>,
#         <UGS-0237-Yttrium-amount>,
#         <UGS-0237-Zinc-amount>,
#         <UGS-0237-Zirconium-amount> ;
#     wgs:lat "53.1231969874352" ;
#     wgs:long "107.37555895932" .
#
# <UGS-0238> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0238-Aluminium_oxide-amount>,
#         <UGS-0238-Arsenic-amount>,
#         <UGS-0238-Barium-amount>,
#         <UGS-0238-Calcium_oxide-amount>,
#         <UGS-0238-Carbon-amount>,
#         <UGS-0238-Cerium-amount>,
#         <UGS-0238-Chromium-amount>,
#         <UGS-0238-Cobalt-amount>,
#         <UGS-0238-Copper-amount>,
#         <UGS-0238-Fluorine-amount>,
#         <UGS-0238-Gallium-amount>,
#         <UGS-0238-Iron(III)_oxide-amount>,
#         <UGS-0238-Lanthanum-amount>,
#         <UGS-0238-Lead-amount>,
#         <UGS-0238-Magnesium_oxide-amount>,
#         <UGS-0238-Manganese(II)_oxide-amount>,
#         <UGS-0238-Neodymium-amount>,
#         <UGS-0238-Nickel-amount>,
#         <UGS-0238-Niobium-amount>,
#         <UGS-0238-Phosphorus_trioxide-amount>,
#         <UGS-0238-Potassium_oxide-amount>,
#         <UGS-0238-Rubidium-amount>,
#         <UGS-0238-Silicon_dioxide-amount>,
#         <UGS-0238-Sodium_oxide-amount>,
#         <UGS-0238-Strontium-amount>,
#         <UGS-0238-Sulfur-amount>,
#         <UGS-0238-Thorium-amount>,
#         <UGS-0238-Tin-amount>,
#         <UGS-0238-Titanium_dioxide-amount>,
#         <UGS-0238-Tungsten-amount>,
#         <UGS-0238-Uranium-amount>,
#         <UGS-0238-Vanadium-amount>,
#         <UGS-0238-Yttrium-amount>,
#         <UGS-0238-Zinc-amount>,
#         <UGS-0238-Zirconium-amount> ;
#     wgs:lat "53.127535963431" ;
#     wgs:long "107.383269974961" .
#
# <UGS-0239> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0239-Aluminium_oxide-amount>,
#         <UGS-0239-Arsenic-amount>,
#         <UGS-0239-Barium-amount>,
#         <UGS-0239-Calcium_oxide-amount>,
#         <UGS-0239-Carbon-amount>,
#         <UGS-0239-Cerium-amount>,
#         <UGS-0239-Chromium-amount>,
#         <UGS-0239-Cobalt-amount>,
#         <UGS-0239-Copper-amount>,
#         <UGS-0239-Fluorine-amount>,
#         <UGS-0239-Gallium-amount>,
#         <UGS-0239-Iron(III)_oxide-amount>,
#         <UGS-0239-Lanthanum-amount>,
#         <UGS-0239-Lead-amount>,
#         <UGS-0239-Magnesium_oxide-amount>,
#         <UGS-0239-Manganese(II)_oxide-amount>,
#         <UGS-0239-Neodymium-amount>,
#         <UGS-0239-Nickel-amount>,
#         <UGS-0239-Niobium-amount>,
#         <UGS-0239-Phosphorus_trioxide-amount>,
#         <UGS-0239-Potassium_oxide-amount>,
#         <UGS-0239-Rubidium-amount>,
#         <UGS-0239-Silicon_dioxide-amount>,
#         <UGS-0239-Sodium_oxide-amount>,
#         <UGS-0239-Strontium-amount>,
#         <UGS-0239-Sulfur-amount>,
#         <UGS-0239-Thorium-amount>,
#         <UGS-0239-Tin-amount>,
#         <UGS-0239-Titanium_dioxide-amount>,
#         <UGS-0239-Tungsten-amount>,
#         <UGS-0239-Uranium-amount>,
#         <UGS-0239-Vanadium-amount>,
#         <UGS-0239-Yttrium-amount>,
#         <UGS-0239-Zinc-amount>,
#         <UGS-0239-Zirconium-amount> ;
#     wgs:lat "53.1637460365891" ;
#     wgs:long "107.370321024209" .
#
# <UGS-0240> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0240-Aluminium_oxide-amount>,
#         <UGS-0240-Arsenic-amount>,
#         <UGS-0240-Barium-amount>,
#         <UGS-0240-Calcium_oxide-amount>,
#         <UGS-0240-Carbon-amount>,
#         <UGS-0240-Cerium-amount>,
#         <UGS-0240-Chromium-amount>,
#         <UGS-0240-Cobalt-amount>,
#         <UGS-0240-Copper-amount>,
#         <UGS-0240-Fluorine-amount>,
#         <UGS-0240-Gallium-amount>,
#         <UGS-0240-Iron(III)_oxide-amount>,
#         <UGS-0240-Lanthanum-amount>,
#         <UGS-0240-Lead-amount>,
#         <UGS-0240-Magnesium_oxide-amount>,
#         <UGS-0240-Manganese(II)_oxide-amount>,
#         <UGS-0240-Neodymium-amount>,
#         <UGS-0240-Nickel-amount>,
#         <UGS-0240-Niobium-amount>,
#         <UGS-0240-Phosphorus_trioxide-amount>,
#         <UGS-0240-Potassium_oxide-amount>,
#         <UGS-0240-Rubidium-amount>,
#         <UGS-0240-Silicon_dioxide-amount>,
#         <UGS-0240-Sodium_oxide-amount>,
#         <UGS-0240-Strontium-amount>,
#         <UGS-0240-Sulfur-amount>,
#         <UGS-0240-Thorium-amount>,
#         <UGS-0240-Tin-amount>,
#         <UGS-0240-Titanium_dioxide-amount>,
#         <UGS-0240-Tungsten-amount>,
#         <UGS-0240-Uranium-amount>,
#         <UGS-0240-Vanadium-amount>,
#         <UGS-0240-Yttrium-amount>,
#         <UGS-0240-Zinc-amount>,
#         <UGS-0240-Zirconium-amount> ;
#     wgs:lat "53.1727239768952" ;
#     wgs:long "107.370815975591" .
#
# <UGS-0241> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0241-Aluminium_oxide-amount>,
#         <UGS-0241-Arsenic-amount>,
#         <UGS-0241-Barium-amount>,
#         <UGS-0241-Calcium_oxide-amount>,
#         <UGS-0241-Carbon-amount>,
#         <UGS-0241-Cerium-amount>,
#         <UGS-0241-Chromium-amount>,
#         <UGS-0241-Cobalt-amount>,
#         <UGS-0241-Copper-amount>,
#         <UGS-0241-Fluorine-amount>,
#         <UGS-0241-Gallium-amount>,
#         <UGS-0241-Iron(III)_oxide-amount>,
#         <UGS-0241-Lanthanum-amount>,
#         <UGS-0241-Lead-amount>,
#         <UGS-0241-Magnesium_oxide-amount>,
#         <UGS-0241-Manganese(II)_oxide-amount>,
#         <UGS-0241-Neodymium-amount>,
#         <UGS-0241-Nickel-amount>,
#         <UGS-0241-Niobium-amount>,
#         <UGS-0241-Phosphorus_trioxide-amount>,
#         <UGS-0241-Potassium_oxide-amount>,
#         <UGS-0241-Rubidium-amount>,
#         <UGS-0241-Silicon_dioxide-amount>,
#         <UGS-0241-Sodium_oxide-amount>,
#         <UGS-0241-Strontium-amount>,
#         <UGS-0241-Sulfur-amount>,
#         <UGS-0241-Thorium-amount>,
#         <UGS-0241-Tin-amount>,
#         <UGS-0241-Titanium_dioxide-amount>,
#         <UGS-0241-Tungsten-amount>,
#         <UGS-0241-Uranium-amount>,
#         <UGS-0241-Vanadium-amount>,
#         <UGS-0241-Yttrium-amount>,
#         <UGS-0241-Zinc-amount>,
#         <UGS-0241-Zirconium-amount> ;
#     wgs:lat "53.1773620191961" ;
#     wgs:long "107.363592032343" .
#
# <UGS-0242> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0242-Aluminium_oxide-amount>,
#         <UGS-0242-Arsenic-amount>,
#         <UGS-0242-Barium-amount>,
#         <UGS-0242-Calcium_oxide-amount>,
#         <UGS-0242-Carbon-amount>,
#         <UGS-0242-Cerium-amount>,
#         <UGS-0242-Chromium-amount>,
#         <UGS-0242-Cobalt-amount>,
#         <UGS-0242-Copper-amount>,
#         <UGS-0242-Fluorine-amount>,
#         <UGS-0242-Gallium-amount>,
#         <UGS-0242-Iron(III)_oxide-amount>,
#         <UGS-0242-Lanthanum-amount>,
#         <UGS-0242-Lead-amount>,
#         <UGS-0242-Magnesium_oxide-amount>,
#         <UGS-0242-Manganese(II)_oxide-amount>,
#         <UGS-0242-Neodymium-amount>,
#         <UGS-0242-Nickel-amount>,
#         <UGS-0242-Niobium-amount>,
#         <UGS-0242-Phosphorus_trioxide-amount>,
#         <UGS-0242-Potassium_oxide-amount>,
#         <UGS-0242-Rubidium-amount>,
#         <UGS-0242-Silicon_dioxide-amount>,
#         <UGS-0242-Sodium_oxide-amount>,
#         <UGS-0242-Strontium-amount>,
#         <UGS-0242-Sulfur-amount>,
#         <UGS-0242-Thorium-amount>,
#         <UGS-0242-Tin-amount>,
#         <UGS-0242-Titanium_dioxide-amount>,
#         <UGS-0242-Tungsten-amount>,
#         <UGS-0242-Uranium-amount>,
#         <UGS-0242-Vanadium-amount>,
#         <UGS-0242-Yttrium-amount>,
#         <UGS-0242-Zinc-amount>,
#         <UGS-0242-Zirconium-amount> ;
#     wgs:lat "53.1819989718496" ;
#     wgs:long "107.356365993618" .
#
# <UGS-0243> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0243-Aluminium_oxide-amount>,
#         <UGS-0243-Arsenic-amount>,
#         <UGS-0243-Barium-amount>,
#         <UGS-0243-Calcium_oxide-amount>,
#         <UGS-0243-Carbon-amount>,
#         <UGS-0243-Cerium-amount>,
#         <UGS-0243-Chromium-amount>,
#         <UGS-0243-Cobalt-amount>,
#         <UGS-0243-Copper-amount>,
#         <UGS-0243-Fluorine-amount>,
#         <UGS-0243-Gallium-amount>,
#         <UGS-0243-Iron(III)_oxide-amount>,
#         <UGS-0243-Lanthanum-amount>,
#         <UGS-0243-Lead-amount>,
#         <UGS-0243-Magnesium_oxide-amount>,
#         <UGS-0243-Manganese(II)_oxide-amount>,
#         <UGS-0243-Neodymium-amount>,
#         <UGS-0243-Nickel-amount>,
#         <UGS-0243-Niobium-amount>,
#         <UGS-0243-Phosphorus_trioxide-amount>,
#         <UGS-0243-Potassium_oxide-amount>,
#         <UGS-0243-Rubidium-amount>,
#         <UGS-0243-Silicon_dioxide-amount>,
#         <UGS-0243-Sodium_oxide-amount>,
#         <UGS-0243-Strontium-amount>,
#         <UGS-0243-Sulfur-amount>,
#         <UGS-0243-Thorium-amount>,
#         <UGS-0243-Tin-amount>,
#         <UGS-0243-Titanium_dioxide-amount>,
#         <UGS-0243-Tungsten-amount>,
#         <UGS-0243-Uranium-amount>,
#         <UGS-0243-Vanadium-amount>,
#         <UGS-0243-Yttrium-amount>,
#         <UGS-0243-Zinc-amount>,
#         <UGS-0243-Zirconium-amount> ;
#     wgs:lat "53.1866350024938" ;
#     wgs:long "107.349139032885" .
#
# <UGS-0244> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0244-Aluminium_oxide-amount>,
#         <UGS-0244-Arsenic-amount>,
#         <UGS-0244-Barium-amount>,
#         <UGS-0244-Calcium_oxide-amount>,
#         <UGS-0244-Carbon-amount>,
#         <UGS-0244-Cerium-amount>,
#         <UGS-0244-Chromium-amount>,
#         <UGS-0244-Cobalt-amount>,
#         <UGS-0244-Copper-amount>,
#         <UGS-0244-Fluorine-amount>,
#         <UGS-0244-Gallium-amount>,
#         <UGS-0244-Iron(III)_oxide-amount>,
#         <UGS-0244-Lanthanum-amount>,
#         <UGS-0244-Lead-amount>,
#         <UGS-0244-Magnesium_oxide-amount>,
#         <UGS-0244-Manganese(II)_oxide-amount>,
#         <UGS-0244-Neodymium-amount>,
#         <UGS-0244-Nickel-amount>,
#         <UGS-0244-Niobium-amount>,
#         <UGS-0244-Phosphorus_trioxide-amount>,
#         <UGS-0244-Potassium_oxide-amount>,
#         <UGS-0244-Rubidium-amount>,
#         <UGS-0244-Silicon_dioxide-amount>,
#         <UGS-0244-Sodium_oxide-amount>,
#         <UGS-0244-Strontium-amount>,
#         <UGS-0244-Sulfur-amount>,
#         <UGS-0244-Thorium-amount>,
#         <UGS-0244-Tin-amount>,
#         <UGS-0244-Titanium_dioxide-amount>,
#         <UGS-0244-Tungsten-amount>,
#         <UGS-0244-Uranium-amount>,
#         <UGS-0244-Vanadium-amount>,
#         <UGS-0244-Yttrium-amount>,
#         <UGS-0244-Zinc-amount>,
#         <UGS-0244-Zirconium-amount> ;
#     wgs:lat "53.1556519679725" ;
#     wgs:long "107.325018011033" .
#
# <UGS-0246> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0246-Aluminium_oxide-amount>,
#         <UGS-0246-Arsenic-amount>,
#         <UGS-0246-Barium-amount>,
#         <UGS-0246-Calcium_oxide-amount>,
#         <UGS-0246-Carbon-amount>,
#         <UGS-0246-Cerium-amount>,
#         <UGS-0246-Chromium-amount>,
#         <UGS-0246-Cobalt-amount>,
#         <UGS-0246-Copper-amount>,
#         <UGS-0246-Fluorine-amount>,
#         <UGS-0246-Gallium-amount>,
#         <UGS-0246-Iron(III)_oxide-amount>,
#         <UGS-0246-Lanthanum-amount>,
#         <UGS-0246-Lead-amount>,
#         <UGS-0246-Magnesium_oxide-amount>,
#         <UGS-0246-Manganese(II)_oxide-amount>,
#         <UGS-0246-Neodymium-amount>,
#         <UGS-0246-Nickel-amount>,
#         <UGS-0246-Niobium-amount>,
#         <UGS-0246-Phosphorus_trioxide-amount>,
#         <UGS-0246-Potassium_oxide-amount>,
#         <UGS-0246-Rubidium-amount>,
#         <UGS-0246-Silicon_dioxide-amount>,
#         <UGS-0246-Sodium_oxide-amount>,
#         <UGS-0246-Strontium-amount>,
#         <UGS-0246-Sulfur-amount>,
#         <UGS-0246-Thorium-amount>,
#         <UGS-0246-Tin-amount>,
#         <UGS-0246-Titanium_dioxide-amount>,
#         <UGS-0246-Tungsten-amount>,
#         <UGS-0246-Uranium-amount>,
#         <UGS-0246-Vanadium-amount>,
#         <UGS-0246-Yttrium-amount>,
#         <UGS-0246-Zinc-amount>,
#         <UGS-0246-Zirconium-amount> ;
#     wgs:lat "53.1602869927883" ;
#     wgs:long "107.317791972309" .
#
# <UGS-0247> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0247-Aluminium_oxide-amount>,
#         <UGS-0247-Arsenic-amount>,
#         <UGS-0247-Barium-amount>,
#         <UGS-0247-Calcium_oxide-amount>,
#         <UGS-0247-Carbon-amount>,
#         <UGS-0247-Cerium-amount>,
#         <UGS-0247-Chromium-amount>,
#         <UGS-0247-Cobalt-amount>,
#         <UGS-0247-Copper-amount>,
#         <UGS-0247-Fluorine-amount>,
#         <UGS-0247-Gallium-amount>,
#         <UGS-0247-Iron(III)_oxide-amount>,
#         <UGS-0247-Lanthanum-amount>,
#         <UGS-0247-Lead-amount>,
#         <UGS-0247-Magnesium_oxide-amount>,
#         <UGS-0247-Manganese(II)_oxide-amount>,
#         <UGS-0247-Neodymium-amount>,
#         <UGS-0247-Nickel-amount>,
#         <UGS-0247-Niobium-amount>,
#         <UGS-0247-Phosphorus_trioxide-amount>,
#         <UGS-0247-Potassium_oxide-amount>,
#         <UGS-0247-Rubidium-amount>,
#         <UGS-0247-Silicon_dioxide-amount>,
#         <UGS-0247-Sodium_oxide-amount>,
#         <UGS-0247-Strontium-amount>,
#         <UGS-0247-Sulfur-amount>,
#         <UGS-0247-Thorium-amount>,
#         <UGS-0247-Tin-amount>,
#         <UGS-0247-Titanium_dioxide-amount>,
#         <UGS-0247-Tungsten-amount>,
#         <UGS-0247-Uranium-amount>,
#         <UGS-0247-Vanadium-amount>,
#         <UGS-0247-Yttrium-amount>,
#         <UGS-0247-Zinc-amount>,
#         <UGS-0247-Zirconium-amount> ;
#     wgs:lat "53.1692650169134" ;
#     wgs:long "107.318276027217" .
#
# <UGS-0249> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0249-Aluminium_oxide-amount>,
#         <UGS-0249-Arsenic-amount>,
#         <UGS-0249-Barium-amount>,
#         <UGS-0249-Calcium_oxide-amount>,
#         <UGS-0249-Carbon-amount>,
#         <UGS-0249-Cerium-amount>,
#         <UGS-0249-Chromium-amount>,
#         <UGS-0249-Cobalt-amount>,
#         <UGS-0249-Copper-amount>,
#         <UGS-0249-Fluorine-amount>,
#         <UGS-0249-Gallium-amount>,
#         <UGS-0249-Iron(III)_oxide-amount>,
#         <UGS-0249-Lanthanum-amount>,
#         <UGS-0249-Lead-amount>,
#         <UGS-0249-Magnesium_oxide-amount>,
#         <UGS-0249-Manganese(II)_oxide-amount>,
#         <UGS-0249-Neodymium-amount>,
#         <UGS-0249-Nickel-amount>,
#         <UGS-0249-Niobium-amount>,
#         <UGS-0249-Phosphorus_trioxide-amount>,
#         <UGS-0249-Potassium_oxide-amount>,
#         <UGS-0249-Rubidium-amount>,
#         <UGS-0249-Silicon_dioxide-amount>,
#         <UGS-0249-Sodium_oxide-amount>,
#         <UGS-0249-Strontium-amount>,
#         <UGS-0249-Sulfur-amount>,
#         <UGS-0249-Thorium-amount>,
#         <UGS-0249-Tin-amount>,
#         <UGS-0249-Titanium_dioxide-amount>,
#         <UGS-0249-Tungsten-amount>,
#         <UGS-0249-Uranium-amount>,
#         <UGS-0249-Vanadium-amount>,
#         <UGS-0249-Yttrium-amount>,
#         <UGS-0249-Zinc-amount>,
#         <UGS-0249-Zirconium-amount> ;
#     wgs:lat "53.177951015532" ;
#     wgs:long "107.333704009652" .
#
# <UGS-0250> a dbp:Sample,
#         owl:NamedIndividual ;
#     <contains> <UGS-0250-Aluminium_oxide-amount>,
#         <UGS-0250-Arsenic-amount>,
#         <UGS-0250-Barium-amount>,
#         <UGS-0250-Calcium_oxide-amount>,
#         <UGS-0250-Carbon-amount>,
#         <UGS-0250-Cerium-amount>,
#         <UGS-0250-Chromium-amount>,
#         <UGS-0250-Cobalt-amount>,
#         <UGS-0250-Copper-amount>,
#         <UGS-0250-Fluorine-amount>,
#         <UGS-0250-Gallium-amount>,
#         <UGS-0250-Iron(III)_oxide-amount>,
#         <UGS-0250-Lanthanum-amount>,
#         <UGS-0250-Lead-amount>,
#         <UGS-0250-Magnesium_oxide-amount>,
#         <UGS-0250-Manganese(II)_oxide-amount>,
#         <UGS-0250-Neodymium-amount>,
#         <UGS-0250-Nickel-amount>,
#         <UGS-0250-Niobium-amount>,
#         <UGS-0250-Phosphorus_trioxide-amount>,
#         <UGS-0250-Potassium_oxide-amount>,
#         <UGS-0250-Rubidium-amount>,
#         <UGS-0250-Silicon_dioxide-amount>,
#         <UGS-0250-Sodium_oxide-amount>,
#         <UGS-0250-Strontium-amount>,
#         <UGS-0250-Sulfur-amount>,
#         <UGS-0250-Thorium-amount>,
#         <UGS-0250-Tin-amount>,
#         <UGS-0250-Titanium_dioxide-amount>,
#         <UGS-0250-Tungsten-amount>,
#         <UGS-0250-Uranium-amount>,
#         <UGS-0250-Vanadium-amount>,
#         <UGS-0250-Yttrium-amount>,
#         <UGS-0250-Zinc-amount>,
#         <UGS-0250-Zirconium-amount> ;
# ...
#     gp:pollutedBy dbp:Vanadium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0267-Yttrium-amount> gp:amount "17." ;
#     gp:pollutedBy dbp:Yttrium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0267-Zinc-amount> gp:amount "127." ;
#     gp:pollutedBy dbp:Zinc ;
#     gp:unit dbp:Percentage .
#
# <UGS-0267-Zirconium-amount> gp:amount "115." ;
#     gp:pollutedBy dbp:Zirconium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Aluminium_oxide-amount> gp:amount "14.28" ;
#     gp:pollutedBy dbp:Aluminium_oxide ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Arsenic-amount> gp:amount "3." ;
#     gp:pollutedBy dbp:Arsenic ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Barium-amount> gp:amount "758." ;
#     gp:pollutedBy dbp:Barium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Calcium_oxide-amount> gp:amount "5.18" ;
#     gp:pollutedBy dbp:Calcium_oxide ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Carbon-amount> gp:amount "7.18" ;
#     gp:pollutedBy dbp:Carbon ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Cerium-amount> gp:amount "54." ;
#     gp:pollutedBy dbp:Cerium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Chromium-amount> gp:amount "104." ;
#     gp:pollutedBy dbp:Chromium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Cobalt-amount> gp:amount "25." ;
#     gp:pollutedBy dbp:Cobalt ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Copper-amount> gp:amount "52." ;
#     gp:pollutedBy dbp:Copper ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Fluorine-amount> gp:amount "521." ;
#     gp:pollutedBy dbp:Fluorine ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Gallium-amount> gp:amount "12." ;
#     gp:pollutedBy dbp:Gallium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Iron(III)_oxide-amount> gp:amount "5.797" ;
#     gp:pollutedBy dbp:Iron(III)_oxide ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Lanthanum-amount> gp:amount "33." ;
#     gp:pollutedBy dbp:Lanthanum ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Lead-amount> gp:amount "18." ;
#     gp:pollutedBy dbp:Lead ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Magnesium_oxide-amount> gp:amount "2.96" ;
#     gp:pollutedBy dbp:Magnesium_oxide ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Manganese(II)_oxide-amount> gp:amount "0.327" ;
#     gp:pollutedBy dbp:Manganese(II)_oxide ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Neodymium-amount> gp:amount "20." ;
#     gp:pollutedBy dbp:Neodymium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Nickel-amount> gp:amount "53." ;
#     gp:pollutedBy dbp:Nickel ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Niobium-amount> gp:amount "8.6" ;
#     gp:pollutedBy dbp:Niobium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Phosphorus_trioxide-amount> gp:amount "0.258" ;
#     gp:pollutedBy dbp:Phosphorus_trioxide ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Potassium_oxide-amount> gp:amount "2.248" ;
#     gp:pollutedBy dbp:Potassium_oxide ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Rubidium-amount> gp:amount "68." ;
#     gp:pollutedBy dbp:Rubidium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Silicon_dioxide-amount> gp:amount "52.42" ;
#     gp:pollutedBy dbp:Silicon_dioxide ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Sodium_oxide-amount> gp:amount "1.958" ;
#     gp:pollutedBy dbp:Sodium_oxide ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Strontium-amount> gp:amount "501." ;
#     gp:pollutedBy dbp:Strontium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Sulfur-amount> gp:amount "250." ;
#     gp:pollutedBy dbp:Sulfur ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Thorium-amount> gp:amount "7.7" ;
#     gp:pollutedBy dbp:Thorium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Tin-amount> gp:amount "4." ;
#     gp:pollutedBy dbp:Tin ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Titanium_dioxide-amount> gp:amount "0.778" ;
#     gp:pollutedBy dbp:Titanium_dioxide ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Tungsten-amount> gp:amount "5." ;
#     gp:pollutedBy dbp:Tungsten ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Uranium-amount> gp:amount "3." ;
#     gp:pollutedBy dbp:Uranium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Vanadium-amount> gp:amount "123." ;
#     gp:pollutedBy dbp:Vanadium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Yttrium-amount> gp:amount "17." ;
#     gp:pollutedBy dbp:Yttrium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Zinc-amount> gp:amount "78." ;
#     gp:pollutedBy dbp:Zinc ;
#     gp:unit dbp:Percentage .
#
# <UGS-0268-Zirconium-amount> gp:amount "83." ;
#     gp:pollutedBy dbp:Zirconium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Aluminium_oxide-amount> gp:amount "11.31" ;
#     gp:pollutedBy dbp:Aluminium_oxide ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Arsenic-amount> gp:amount "4.2" ;
#     gp:pollutedBy dbp:Arsenic ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Barium-amount> gp:amount "880." ;
#     gp:pollutedBy dbp:Barium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Calcium_oxide-amount> gp:amount "4.85" ;
#     gp:pollutedBy dbp:Calcium_oxide ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Carbon-amount> gp:amount "9.8" ;
#     gp:pollutedBy dbp:Carbon ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Cerium-amount> gp:amount "63." ;
#     gp:pollutedBy dbp:Cerium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Chromium-amount> gp:amount "114." ;
#     gp:pollutedBy dbp:Chromium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Cobalt-amount> gp:amount "20." ;
#     gp:pollutedBy dbp:Cobalt ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Copper-amount> gp:amount "36." ;
#     gp:pollutedBy dbp:Copper ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Fluorine-amount> gp:amount "478." ;
#     gp:pollutedBy dbp:Fluorine ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Gallium-amount> gp:amount "11." ;
#     gp:pollutedBy dbp:Gallium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Iron(III)_oxide-amount> gp:amount "3.604" ;
#     gp:pollutedBy dbp:Iron(III)_oxide ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Lanthanum-amount> gp:amount "44." ;
#     gp:pollutedBy dbp:Lanthanum ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Lead-amount> gp:amount "22." ;
#     gp:pollutedBy dbp:Lead ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Magnesium_oxide-amount> gp:amount "2.3" ;
#     gp:pollutedBy dbp:Magnesium_oxide ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Manganese(II)_oxide-amount> gp:amount "0.414" ;
#     gp:pollutedBy dbp:Manganese(II)_oxide ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Neodymium-amount> gp:amount "21." ;
#     gp:pollutedBy dbp:Neodymium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Nickel-amount> gp:amount "69." ;
#     gp:pollutedBy dbp:Nickel ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Niobium-amount> gp:amount "8.3" ;
#     gp:pollutedBy dbp:Niobium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Phosphorus_trioxide-amount> gp:amount "0.297" ;
#     gp:pollutedBy dbp:Phosphorus_trioxide ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Potassium_oxide-amount> gp:amount "2.535" ;
#     gp:pollutedBy dbp:Potassium_oxide ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Rubidium-amount> gp:amount "94." ;
#     gp:pollutedBy dbp:Rubidium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Silicon_dioxide-amount> gp:amount "51.99" ;
#     gp:pollutedBy dbp:Silicon_dioxide ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Sodium_oxide-amount> gp:amount "1.023" ;
#     gp:pollutedBy dbp:Sodium_oxide ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Strontium-amount> gp:amount "434." ;
#     gp:pollutedBy dbp:Strontium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Sulfur-amount> gp:amount "399." ;
#     gp:pollutedBy dbp:Sulfur ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Thorium-amount> gp:amount "8.5" ;
#     gp:pollutedBy dbp:Thorium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Tin-amount> gp:amount "4." ;
#     gp:pollutedBy dbp:Tin ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Titanium_dioxide-amount> gp:amount "0.523" ;
#     gp:pollutedBy dbp:Titanium_dioxide ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Tungsten-amount> gp:amount "5." ;
#     gp:pollutedBy dbp:Tungsten ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Uranium-amount> gp:amount "3." ;
#     gp:pollutedBy dbp:Uranium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Vanadium-amount> gp:amount "94." ;
#     gp:pollutedBy dbp:Vanadium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Yttrium-amount> gp:amount "23." ;
#     gp:pollutedBy dbp:Yttrium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Zinc-amount> gp:amount "112." ;
#     gp:pollutedBy dbp:Zinc ;
#     gp:unit dbp:Percentage .
#
# <UGS-0269-Zirconium-amount> gp:amount "94." ;
#     gp:pollutedBy dbp:Zirconium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Aluminium_oxide-amount> gp:amount "10.5" ;
#     gp:pollutedBy dbp:Aluminium_oxide ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Arsenic-amount> gp:amount "3." ;
#     gp:pollutedBy dbp:Arsenic ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Barium-amount> gp:amount "894." ;
#     gp:pollutedBy dbp:Barium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Calcium_oxide-amount> gp:amount "1.43" ;
#     gp:pollutedBy dbp:Calcium_oxide ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Carbon-amount> gp:amount "6." ;
#     gp:pollutedBy dbp:Carbon ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Cerium-amount> gp:amount "35." ;
#     gp:pollutedBy dbp:Cerium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Chromium-amount> gp:amount "38." ;
#     gp:pollutedBy dbp:Chromium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Cobalt-amount> gp:amount "6.9" ;
#     gp:pollutedBy dbp:Cobalt ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Copper-amount> gp:amount "16." ;
#     gp:pollutedBy dbp:Copper ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Fluorine-amount> gp:amount "276." ;
#     gp:pollutedBy dbp:Fluorine ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Gallium-amount> gp:amount "8." ;
#     gp:pollutedBy dbp:Gallium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Iron(III)_oxide-amount> gp:amount "1.278" ;
#     gp:pollutedBy dbp:Iron(III)_oxide ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Lanthanum-amount> gp:amount "20." ;
#     gp:pollutedBy dbp:Lanthanum ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Lead-amount> gp:amount "28." ;
#     gp:pollutedBy dbp:Lead ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Magnesium_oxide-amount> gp:amount "0.73" ;
#     gp:pollutedBy dbp:Magnesium_oxide ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Manganese(II)_oxide-amount> gp:amount "0.274" ;
#     gp:pollutedBy dbp:Manganese(II)_oxide ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Neodymium-amount> gp:amount "17." ;
#     gp:pollutedBy dbp:Neodymium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Nickel-amount> gp:amount "18." ;
#     gp:pollutedBy dbp:Nickel ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Niobium-amount> gp:amount "5.9" ;
#     gp:pollutedBy dbp:Niobium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Phosphorus_trioxide-amount> gp:amount "0.157" ;
#     gp:pollutedBy dbp:Phosphorus_trioxide ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Potassium_oxide-amount> gp:amount "2.733" ;
#     gp:pollutedBy dbp:Potassium_oxide ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Rubidium-amount> gp:amount "98." ;
#     gp:pollutedBy dbp:Rubidium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Silicon_dioxide-amount> gp:amount "70.57" ;
#     gp:pollutedBy dbp:Silicon_dioxide ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Sodium_oxide-amount> gp:amount "1.048" ;
#     gp:pollutedBy dbp:Sodium_oxide ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Strontium-amount> gp:amount "232." ;
#     gp:pollutedBy dbp:Strontium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Sulfur-amount> gp:amount "184." ;
#     gp:pollutedBy dbp:Sulfur ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Thorium-amount> gp:amount "6." ;
#     gp:pollutedBy dbp:Thorium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Tin-amount> gp:amount "4." ;
#     gp:pollutedBy dbp:Tin ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Titanium_dioxide-amount> gp:amount "0.314" ;
#     gp:pollutedBy dbp:Titanium_dioxide ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Tungsten-amount> gp:amount "5." ;
#     gp:pollutedBy dbp:Tungsten ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Uranium-amount> gp:amount "3." ;
#     gp:pollutedBy dbp:Uranium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Vanadium-amount> gp:amount "44." ;
#     gp:pollutedBy dbp:Vanadium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Yttrium-amount> gp:amount "16." ;
#     gp:pollutedBy dbp:Yttrium ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Zinc-amount> gp:amount "95." ;
#     gp:pollutedBy dbp:Zinc ;
#     gp:unit dbp:Percentage .
#
# <UGS-0270-Zirconium-amount> gp:amount "65." ;
#     gp:pollutedBy dbp:Zirconium ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Aluminium_oxide-amount> gp:amount "11.03" ;
#     gp:pollutedBy dbp:Aluminium_oxide ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Arsenic-amount> gp:amount "3." ;
#     gp:pollutedBy dbp:Arsenic ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Barium-amount> gp:amount "798." ;
#     gp:pollutedBy dbp:Barium ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Calcium_oxide-amount> gp:amount "1.93" ;
#     gp:pollutedBy dbp:Calcium_oxide ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Carbon-amount> gp:amount "9.6" ;
#     gp:pollutedBy dbp:Carbon ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Cerium-amount> gp:amount "40." ;
#     gp:pollutedBy dbp:Cerium ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Chromium-amount> gp:amount "52." ;
#     gp:pollutedBy dbp:Chromium ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Cobalt-amount> gp:amount "9." ;
#     gp:pollutedBy dbp:Cobalt ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Copper-amount> gp:amount "17." ;
#     gp:pollutedBy dbp:Copper ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Fluorine-amount> gp:amount "326." ;
#     gp:pollutedBy dbp:Fluorine ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Gallium-amount> gp:amount "10." ;
#     gp:pollutedBy dbp:Gallium ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Iron(III)_oxide-amount> gp:amount "2.042" ;
#     gp:pollutedBy dbp:Iron(III)_oxide ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Lanthanum-amount> gp:amount "26." ;
#     gp:pollutedBy dbp:Lanthanum ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Lead-amount> gp:amount "26." ;
#     gp:pollutedBy dbp:Lead ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Magnesium_oxide-amount> gp:amount "0.95" ;
#     gp:pollutedBy dbp:Magnesium_oxide ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Manganese(II)_oxide-amount> gp:amount "0.262" ;
#     gp:pollutedBy dbp:Manganese(II)_oxide ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Neodymium-amount> gp:amount "18." ;
#     gp:pollutedBy dbp:Neodymium ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Nickel-amount> gp:amount "24." ;
#     gp:pollutedBy dbp:Nickel ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Niobium-amount> gp:amount "7.3" ;
#     gp:pollutedBy dbp:Niobium ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Phosphorus_trioxide-amount> gp:amount "0.138" ;
#     gp:pollutedBy dbp:Phosphorus_trioxide ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Potassium_oxide-amount> gp:amount "2.703" ;
#     gp:pollutedBy dbp:Potassium_oxide ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Rubidium-amount> gp:amount "97." ;
#     gp:pollutedBy dbp:Rubidium ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Silicon_dioxide-amount> gp:amount "67.13" ;
#     gp:pollutedBy dbp:Silicon_dioxide ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Sodium_oxide-amount> gp:amount "1.154" ;
#     gp:pollutedBy dbp:Sodium_oxide ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Strontium-amount> gp:amount "223." ;
#     gp:pollutedBy dbp:Strontium ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Sulfur-amount> gp:amount "207." ;
#     gp:pollutedBy dbp:Sulfur ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Thorium-amount> gp:amount "6.4" ;
#     gp:pollutedBy dbp:Thorium ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Tin-amount> gp:amount "4." ;
#     gp:pollutedBy dbp:Tin ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Titanium_dioxide-amount> gp:amount "0.463" ;
#     gp:pollutedBy dbp:Titanium_dioxide ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Tungsten-amount> gp:amount "5." ;
#     gp:pollutedBy dbp:Tungsten ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Uranium-amount> gp:amount "3." ;
#     gp:pollutedBy dbp:Uranium ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Vanadium-amount> gp:amount "59." ;
#     gp:pollutedBy dbp:Vanadium ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Yttrium-amount> gp:amount "18." ;
#     gp:pollutedBy dbp:Yttrium ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Zinc-amount> gp:amount "66." ;
#     gp:pollutedBy dbp:Zinc ;
#     gp:unit dbp:Percentage .
#
# <UGW-0264-Zirconium-amount> gp:amount "142." ;
#     gp:pollutedBy dbp:Zirconium ;
#     gp:unit dbp:Percentage .
#
# dbp:Sample a owl:Class .

# %%
graph.serialize(format='ttl', destination='database-from-python.ttl', base = BASE)
# Out:
# <Graph identifier=Nef187508916b42f3967601cd2f1b7b1b (<class 'rdflib.graph.Graph'>)>
